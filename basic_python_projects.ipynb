# %% [markdown]
# # 1 -  Projet liste de courses

# %% [markdown]
# Dans ce projet, tu vas devoir créer un programme en ligne de commande qui permet de manipuler une liste de courses.
#
# **Déroulé du script**
#
# Le programme doit permettre de réaliser 5 actions :
#
# 1. Ajouter un élément à la liste de courses
#
# 2. Retirer un élément de la liste de courses
#
# 3. Afficher les éléments de la liste de courses
#
# 4. Vider la liste de courses
#
# 5. Quitter le programme
#
# **Tu dois donc demander** à l'utilisateur de choisir parmi une de ces action en entrant un nombre de 1 à 5.
#
# Tu dois gérer le cas de figure où l'utilisateur ne rentre pas un nombre compris entre 1 et 5 ou s'il rentre par exemple des lettres ou un autre symbole invalide. Dans ce cas, tu dois afficher de nouveau le menu avec les options disponibles, jusqu'à ce que l'utilisateur choisisse une option valide.
#
# Dans ce projet, tu ne dois pas sauvegarder la liste dans un fichier ou une base de donnée.
#
# Le but ici est juste d'interagir avec l'utilisateur et de manipuler une liste en fonction de son choix.
#
# Bonne chance pour cet exercice ?
#
# Prends le temps de bien décrire toutes les étapes en français avant de te lancer dans le code !

# %%
import sys

liste = []
choix = "0"
while choix != "5":
    print('''Choisissez parmi les 5 options suivantes : \n
    1: Ajouter un élément à la liste \n
    2: Retirer un élément de la liste \n
    3: Afficher la liste \n
    4: Vider la liste \n
    5: Quitter \n
    ''')
    
    choix = input("Votre choix : ")
    

    while not (choix.isdigit() and int(choix) in range(1, 6)):
      print("Pour votre choix, rentrer un chiffre entre 1 et 5")
      #Redemander à l'utilisateur de faire un choix valide
      print('''Choisissez parmi les 5 options suivantes : \n
      1: Ajouter un élément à la liste \n
      2: Retirer un élément de la liste \n
      3: Afficher la liste \n
      4: Vider la liste \n
      5: Quitter \n
      ''')
      choix = input("Votre choix : ")
    #On sort avec une chaîne de caractère de nombre, qu'on convertit en int
    choix_conv_num = int(choix)
          
    if choix == "1":
      #Ajouter un élément à la liste de courses
      element_a_ajoute = input("Entrer le nom d'un élément à ajouter à la liste de courses : ")
      #Vérifier si l'élément à ajouter existe déjà dans la liste de courses ou pas
      if not element_a_ajoute in liste:
        liste.append(element_a_ajoute)
      else:
        print("L'élément que vous voulez ajouté à la liste de courses existe déjà")

    elif choix == "2":
      #Retirer un élément à la liste de courses
      element_a_retire = input("Entre le nom de l'élément à retirer : ")
      #Vérifier si l'élément à ajouter existe déjà dans la liste de courses ou
      if element_a_retire in liste:
        liste.remove(element_a_retire)
      else:
        print("L'élément que vous voulez retirer n'existe pas dans la liste")

    elif choix == "3":
      #Afficher les éléments de la liste de courses
      print(liste)

    elif choix == "4":
      #Vider la liste de courses
      liste.clear()

    elif choix == "5":
      #Quitter le programme
      print("À bientôt !")
      #sys.exit()

# %% [markdown]
# # 2 -  Projet mystère

# %% [markdown]
# Le but de ce projet est de permettre à un joueur d'essayer de deviner un nombre mystère généré aléatoirement par l'ordinateur, en 5 essais ou moins.
#
# **Déroulé du script**
#
# Au début du script, vous devez générer un nombre aléatoire compris entre 0 et 100 (vous pouvez agrandir ou réduire cet intervalle pour simplifier ou complexifier le jeu).
#
# Le joueur dispose alors de 5 essais (là encore, libre à vous de changer cette valeur) pour trouver le nombre mystère.
#
# À chaque essai, vous devez indiquer au joueur si le nombre qu'il a entré est plus petit ou plus grand que le nombre mystère.
#
# Si le nombre entré par l'utilisateur est égal au nombre mystère, alors le joueur gagne la partie.
#
# Dans le cas d'une victoire, vous devez indiquer au joueur combien d'essais lui ont été nécessaire pour gagner.
#
# Si le joueur ne trouve pas le nombre mystère avec les 5 essais disponibles, il perd la partie.

# %%
import random

#Le nombre aléatoire compris entre 0 et 100 généré par l'ordinateur
nombre_aleatoire = random.randint(0, 100)
#Nombre d'éssais total
nombre_essais = 5

#Nombre d'essais effectués
nombre_essais_effectues = 0


#Début du Jeu mystère
print(f"***Le jeu du nombre mystère***")


for i in range(nombre_essais):
    #Nombre d'essais restants
    nombre_essais_restants = nombre_essais - nombre_essais_effectues
    
    print(f"Il vous reste {nombre_essais_restants} essais")
    nombre_saisi = input("Deviner le nombre : ")
    
    nombre_essais_effectues += 1

    
    while not (nombre_saisi.isdigit() and 0 <= int(nombre_saisi) <=100):
        print("Veuillez entrer un nombre valide (un entier entre 0 et 100)")
        print(f"Il vous reste {nombre_essais_restants} essais")
        nombre_saisi = input("Deviner le nombre : ")
    
    #Conversion en int du nombre_saisi
    nombre_saisi = int(nombre_saisi)
    
    if nombre_saisi == nombre_aleatoire:
        print (f"Bravo ! le nombre mystère était {nombre_aleatoire}")
        print(f"Vous avez trouvé ce nombre en {nombre_essais_effectues} essais")
        print("Fin du jeu !")
        break
        
    elif nombre_saisi > nombre_aleatoire:
        print(f"Le nombre mystère est plus petit que {nombre_saisi}")
        
    else:
        print(f"Le nombre mystère est plus grand que {nombre_saisi}")
            
if nombre_essais_effectues == nombre_essais and nombre_saisi != nombre_aleatoire:
    print(f"Dommage ! Le nombre mystère était {nombre_aleatoire}")
    print("Fin du jeu")

# %% [markdown]
# # 3 - Projet Jeu de rôle

# %% [markdown]
# **Règles du jeu**
#
# Le but de ce projet est de créer un jeu de rôle textuel dans le terminal.
#
# - Le jeu comporte deux joueurs : vous et un ennemi.
#
# - Vous commencez tous les deux avec 50 points de vie.
#
# - Votre personnage dispose de 3 potions qui vous permettent de récupérer des points de vie.
#
# - L'ennemi ne dispose d'aucune potion.
#
# - Chaque potion vous permet de récupérer un nombre aléatoire de points de vie, compris entre 15 et 50.
#
# - Votre attaque inflige à l'ennemi des dégâts aléatoires compris entre 5 et 10 points de vie.
#
# - L'attaque de l'ennemi vous inflige des dégâts aléatoires compris entre 5 et 15 points de vie.
#
# - Lorsque vous utilisez une potion, vous passez le prochain tour.
#
# **Déroulé de la partie**
#
# Lorsque vous lancez le script, vous devez demander à l'utilisateur s'il souhaite attaquer ou utiliser une potion :
#
# "Souhaitez-vous attaquer (1) ou utiliser une potion (2) ? "
#
# Cette phrase sera demandée à l'utilisateur au début de chaque tour.
#
# 👉  Si l'utilisateur choisi la première option (1), vous infligez des points de dégât à l'ennemi.
#
# Ces points seront compris entre 5 et 10 et déterminés aléatoirement par le programme.
#
# 👉  Si l'utilisateur choisi la deuxième option (2), vous prenez une potion.
#
# Les points de vie que la potion vous donne doivent être compris entre 15 et 50 et générés aléatoirement par le programme Python.
#
# Vous devez vérifier que l'utilisateur dispose de suffisamment de potion et décrémenter le nombre de potions qu'il a dans son inventaire lorsqu'il en boit une. Si l'utilisateur n'a plus de potions, vous devez lui indiquer et lui proposer de nouveau de faire un choix (attaquer ou prendre une potion).
#
# Quand le joueur prend une potion, il passe le prochain tour.
#
# Une fois l'action du joueur exécutée, et si l'ennemi est encore vivant, il vous attaque. Si l'ennemi est mort, vous pouvez terminer le jeu et indiqué à l'utilisateur qu'il a gagné ?
#
# L'attaque de l'ennemi inflige des dégâts au joueur compris entre 5 et 15, là encore déterminés aléatoirement par le script.
#
# Si vous n'avez plus de points de vie, le jeu se termine et vous avez perdu la partie.
#
# À la fin du tour, vous devez afficher le nombre de points de vie restants du joueur et de l'ennemi.
#
# Toutes ces opérations se répètent tant que le joueur et l'ennemi sont en vie.
#
# À chaque tour, vous attaquez en premier. Il ne peut donc pas y avoir de match nul. Si lorsque vous attaquez, votre attaque fait descendre les points de vie de l'ennemi en dessous de (ou égal à) 0, vous gagnez la partie sans que l'ennemi n'ait le temps de vous attaquer en retour.
#
# Questions for this assignment
# Comment créer un jeu de rôle style année 80 dans le terminal ?

# %%
from random import randint

#Votre point de vie
votre_points_de_vie = 50

#Point de vie de l'ennemi
ennemi_points_de_vie = 50

#Nombre de potions
nombre_de_potions = 3

#Points récupérer par une potion
points_recupere_par_potion = randint(15, 50)

#Le dégât que votre attaque cause à l'ennemi
votre_degat_a_ennemi = randint(5,10)

#Le dégât que l'attaque de lennemi vous cause
ennemi_degat_a_vous = randint(5, 15)

#Reponses
rep_1 = 1
rep_2 = 2

#Un capteur qui permet de me dire si j'ai faix le choix 2 (False si je rentre le choix 2) pour ne plus attaquer l'ennemi au prochain tour
capteur = True


while votre_points_de_vie > 0 and ennemi_points_de_vie > 0:
    
    if capteur:
        print("-"*20)
        
        reponse = input(f"Souhaitez-vous attaquer ({rep_1}) ou utiliser une potion ({rep_2}) ")
    
        while not (reponse.isdigit() and  1<= int(reponse) <= 2):
            print(f"Entrer un choix valide (entre ({rep_1}) attaquer ou ({rep_2}) utiliser une potion")
            reponse = input(f"Souhaitez-vous attaquer ({rep_1}) ou utiliser une potion ({rep_2}) ")
            
    else:
        print("-"*20)
        
        #Vous passez le prochain tour
        print("Vous passez votre tour")
        
        #Le dégât que l'attaque de lennemi vous cause
        ennemi_degat_a_vous = randint(5, 15)

        print(f"L'ennemi vous a infligé {ennemi_degat_a_vous} points de dégâts ⚔️")

        #Points restants à vous
        votre_points_de_vie -= ennemi_degat_a_vous

        #Affichage des points restants
        print(f"Il vous reste {votre_points_de_vie} points de vie ❤️.")
        print(f"Il reste {ennemi_points_de_vie} points de vie ❤️ à l'ennemi.")
        
        #Remettons le capteur à true au tour suivant 
        capteur = True
        
        continue
    
    reponse = int(reponse)
    
    
    
    if reponse == 1:
        #Le dégât que votre attaque cause à l'ennemi
        votre_degat_a_ennemi = randint(5,10)

        print(f"Vous avez infligé {votre_degat_a_ennemi} points de dégâts à l'ennemi ⚔️")

        #Point restant à ennemi
        ennemi_points_de_vie -= votre_degat_a_ennemi

        #Le dégât que l'attaque de lennemi vous cause
        ennemi_degat_a_vous = randint(5, 15)

        print(f"L'ennemi vous a infligé {ennemi_degat_a_vous} points de dégâts ⚔️")

        #Point restant à vous
        votre_points_de_vie -= ennemi_degat_a_vous

        #Les points restants
        print(f"Il vous reste {votre_points_de_vie} points de vie ❤️.")
        print(f"Il reste {ennemi_points_de_vie} points de vie ❤️ à l'ennemi.") 
        continue
        
    elif reponse == 2 and nombre_de_potions == 0:
        print(f"Vous n'avez plus de potions... Faites le choix ({rep_1})")
        continue

    
    elif reponse == 2 and nombre_de_potions > 0:
        capteur = False
        #Le point que vous récupérer grâce au potion
        points_recupere_par_potion = randint(15, 50)

        votre_points_de_vie += points_recupere_par_potion 

        #potions restantes
        nombre_de_potions -= 1

        print(f"Vous avez récupéré {points_recupere_par_potion} points de vie ❤️ ({nombre_de_potions} restantes 🧪).")

        #Le dégât que l'attaque de lennemi vous cause
        ennemi_degat_a_vous = randint(5, 15)

        print(f"L'ennemi vous a infligé {ennemi_degat_a_vous} points de dégâts ⚔️")

        #Points restants à vous
        votre_points_de_vie -= ennemi_degat_a_vous

        #Affichage des points restants
        print(f"Il vous reste {votre_points_de_vie} points de vie ❤️.")
        print(f"Il reste {ennemi_points_de_vie} points de vie ❤️ à l'ennemi.")
    
if votre_points_de_vie > ennemi_points_de_vie:
    print("\n")
    print("Vous avez gagné 💪\n")

else:
    print("\n")
    print("Désolé, vous avez perdu 😔\n")

print("Fin du jeu.")
